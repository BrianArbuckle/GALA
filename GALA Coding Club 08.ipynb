# %% [markdown]
# # ZIP Codes Part 1
#
# We have talked about `lists`, `dictionaries`, and `sets`. We will cover `Tuples` at a later date.
#
# ## A List
#
# A **list** is a collection of items in a particular order. You can make a list that includes the letters of the alphabet, the digits from 0–9, or the names of all the people in your family. You can put anything you want into a list, and the items in your list don’t have to be related in any particular way. Because a list usually contains more than one element, it’s a good idea to make the name of your list plural, such as letters, digits, or names.
# In Python, square brackets `[]` indicate a list, and individual elements in the list are separated by commas.
#
# ## Dictionary
#
# A **dictionary** in Python is a collection of key-value pairs. Each key is connected to a value, and you can use a key to access the value associated with that key. A key’s value can be a number, a string, a list, or even another dictionary.<br>
# In fact, you can use any object that you can create in Python as a value in a dictionary.
# In Python, a dictionary is wrapped in braces, `{}`, with a series of key- value pairs inside the braces
#
# ## Set
#
# Python **Sets** are like lists in many ways, however they have different fewer methods, and are in no particular order.  You can create sets two ways.  A function or assing your values in `{}`.<br>  If you racall we talked about the Venn Diagram. And the Union and Interesction, which are methods that can be used on a set.
#
# And the other great feature, sets have no duplicates, so converting a list, such as tons of zip codes or the best name ever, we can create a set of unique value.

# %%
zip_codes = [90021, 90021, 90123, 90123, 90123, 90036, 90218, 90036, 90027, 90036, 90036, 90027, 90036, 90048,
            90027,  90048, 90021, 90123, 90321, 90218, 90200, 90048, 90048, 90027, 90005, 90036, 90021]

len(zip_codes)
# Out:
# 27

# %% [markdown]
# ### Select the Unique Values with the `Set()` Function
# To find the unique zip codes all we need to do is convert this list to a set, which is quite easy with the `Set` funtion.

# %%
unique_zips = set(zip_codes)

# %%
unique_zips
# Out:
# {90005, 90021, 90027, 90036, 90048, 90123, 90200, 90218, 90321}

# %%
len(unique_zips)
# Out:
# 9

# %% [markdown]
# ### Using the Set of Unique Zip Codes to loop though and `count()` all the zip codes
#
# Introducing the `count()` method.

# %%
zip_count = {}

for zip_code in unique_zips:
    zip_count[zip_code] = zip_codes.count(zip_code)

print(zip_count)
# Out:
# {90048: 4, 90021: 4, 90218: 2, 90027: 4, 90123: 4, 90321: 1, 90036: 6, 90005: 1, 90200: 1}

# %%
import math

pi = math.pi
print(pi)
# Out:
# 3.141592653589793

# %%
from collections import Counter

new_zips = dict(Counter(zip_codes))
print(new_zips)
# Out:
# {90021: 4, 90123: 4, 90036: 6, 90218: 2, 90027: 4, 90048: 4, 90321: 1, 90200: 1, 90005: 1}

# %% [markdown]
# ### A brief intro to Matplotlib
#
# **`matplotlib`** a mathematical plotting library, is one of the most popular python tools. We’ll use matplotlib to make simple plots, such as line graphs and scatter plots. After which, we’ll create a more interesting data set based on the zip code. We will dive into this after Thanksgiving, though I want to show you some of the data we are working with.

# %%
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg'

x = [1, 2, 3, 4, 5]
y = [1, 3, 2, 4, 6]

plt.plot(x,y)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.bar(x,y)
plt.show()

# %%
x = zip_count.keys()
y = zip_count.values()

plt.bar(x,y)
plt.show()

# %%
zip_count = {}

for zip_code in unique_zips:
    zip_count[str(zip_code)] = zip_codes.count(zip_code)

print(zip_count)
# Out:
# {'90048': 4, '90021': 4, '90218': 2, '90027': 4, '90123': 4, '90321': 1, '90036': 6, '90005': 1, '90200': 1}

# %%
x = zip_count.keys()
y = zip_count.values()

plt.bar(x,y)
plt.show()
